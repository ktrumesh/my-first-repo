# %% [markdown]
# <a href="https://colab.research.google.com/github/ktrumesh/my-first-repo/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello GitHub")
# Out:
# Hello GitHub

# %%
a = 10
a +=10
a
# Out:
# 20

# %%
print ("Hello Github")
# Out:
# Hello Github

# %%
# creating a list
a =

# %%
# comparision of two numbers
a= int(input("enter the value of a: "))
b= int(input("enter the value of b: "))

if a>b:
  print ("a is greater than b")

else:
  print ("b is greater than a")
# Out:
# enter the value of a: 2502
# enter the value of b: 2101
# a is greater than b

# %%
a= int(input(" enter the value of a: "))
if a%2 == 0:
  print ("a is even number")
else:
  print ("a is a odd number")
# Out:
#  enter the value of a: 13
# a is a odd number

# %%
a= int(input(" enter the value of a: "))
if a%2 == 0:
  print ("a is even number")
else:
  print ("a is a odd number")
# Out:
#  enter the value of a: 202
# a is even number

# %%
marks = 50
attendance = 50

if attendance >30:
  if marks > 35:
    print ("student is passed")

  else:
    print ("student is failed")

else:
  print("try again")
# Out:
# student is passed

# %%
marks = 50
attendance = 50

if attendance > 70:
  if marks > 80:
    print ("student is passed")

  else:
    print ("student is failed")

else:
  print("try again")
# Out:
# try again

# %%
marks = 50
attendance = 75

if attendance > 70:
  if marks > 80:
    print ("student is passed")

  else:
    print ("student is failed")

else:
  print("try again")
# Out:
# student is failed

# %%
def calculator():
  print("select operation:")
  print("1.Addition (+)")
  print("2.Subtraction (-)")
  print("3.Multiplication (*)")
  print("4.Division (/)")
  print("5.Floor Division (//)")
  print("6.Modulus (%)")
  print("7.Exponent (**)")

  choice = input("Enter choice (1/2/3/4/5/6/7 or +,-,*,/,//,%,**): ")

  if choice in ("1", "2", "3", "4", "5", "6", "7", "+", "-", "*", "/", "//", "%","**"):
    try:
      num1 = float(input("Enter first number: "))
      num2 = float(input("Enter second number: "))
    except ValueError:
      print("Invalid input. Please enter a number.")
      return

    if choice in ("1", "+"):
      result = num1 + num2
      print(f"{num1} + {num2} = {result}")
    elif choice in ("2", "-"):
      result = num1 - num2
      print(f"{num1} - {num2} = {result}")
    elif choice in ("3", "*"):
      result = num1 * num2
      print(f"{num1} * {num2} = {result}")
    elif choice in ("4", "/"):
      if num2 == 0:
        print("Error: Division by zero")
      else:
        result = num1 / num2
        print(f"{num1} / {num2} = {result}")
    elif choice in ("5", "//"):
      if num2 == 0:
        print("Error: Division by zero")
      else:
        result = num1 // num2
        print(f"{num1} // {num2} = {result}")
    elif choice in ("6", "%"):
      if num2 == 0:
        print("Error: Division by zero")
      else:
        result = num1 % num2
        print(f"{num1} % {num2} = {result}")
    elif choice in ("7", "**"):
      result = num1 ** num2
      print(f"{num1} ** {num2} = {result}")

  else:
    print("Invalid operation selection.")

calculator()
# Out:
# select operation:
# 1.Addition (+)
# 2.Subtraction (-)
# 3.Multiplication (*)
# 4.Division (/)
# 5.Floor Division (//)
# 6.Modulus (%)
# 7.Exponent (**)
# Enter choice (1/2/3/4/5/6/7 or +,-,*,/,//,%,**): 7
# Enter first number: 5
# Enter second number: 2
# 5.0 ** 2.0 = 25.0
